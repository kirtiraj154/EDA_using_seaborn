# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KIRTI RAJ PRADHAN'

# %%
os.chdir("C:\\Users\\KIRTI RAJ PRADHAN\\Downloads")

# %%
df=pd.read_excel("total_bill.xlsx")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
continous=["total_bill","tip"]
discrete=["sex","smoker","day","time","size"]

# %%
df[continous].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
df[continous].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
df.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.describe(include='object')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['total_bill'].value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %%
df[["smoker","day","size"]].value_counts()
# Out:
# smoker  day   size
# No      Thur  2       35
# Yes     Sat   2       28
# No      Sun   2       27
#         Sat   2       25
#         Sun   4       16
# Yes     Fri   2       13
#         Thur  2       13
# No      Sat   3       12
# Yes     Sun   2       12
# No      Sun   3       11
#         Sat   4        7
# Yes     Sat   4        6
#               3        6
#         Sun   3        4
# No      Fri   2        3
#         Thur  6        3
#               4        3
#               3        2
#         Sun   5        2
# Yes     Sun   4        2
#         Thur  3        2
#               4        2
# No      Fri   3        1
# Yes     Fri   1        1
# No      Thur  5        1
# Yes     Fri   4        1
#         Sat   1        1
# No      Thur  1        1
# Yes     Sat   5        1
# No      Sun   6        1
# Yes     Sun   5        1
# No      Sat   1        1
# dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # Plot's for continous data
# ## univariate(single variable)
# ##   1) Histogram
# ##   2) Box plot
# ## Bivariate(plot between two variables)
# ##   1)scatter plot
# ##   2)Line plot
# ##   3)Joint plot
# ##   4)Vilolin plot
# ## Multivariate(More than two variables)
# ##   1)Pair plot
# ##   2)Heatmap

# %%
sns.histplot(df["total_bill"],kde=True,bins=12)
plt.show()

# %%
#Histogram
sns.displot(df['total_bill'],bins=10)
plt.show()

# %%
sns.displot(df['total_bill'],bins=10,kde=True)    #kde=kernal density estimate 
plt.show()

# %%
#Box plot
sns.boxplot(df['total_bill'])
plt.show()
# Out:
# C:\Users\KIRTI RAJ PRADHAN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(y=df['total_bill'])    #for rotating the box plot use y-
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
sns.boxplot(x=df['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.boxplot(x=df['size'])
# Out:
# <AxesSubplot:xlabel='size'>

# %%
#scatter plot for double variable
sns.scatterplot(y=df['total_bill'],x=df['tip'])
plt.show()

# %%
sns.relplot(x=df['total_bill'],y=df['tip'])
plt.show()

# %%
sns.relplot(y=df['total_bill'],x=df['tip'])
plt.show()

# %%
sns.scatterplot(y=df['total_bill'],x=df['tip'])
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='smoker')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='sex')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,style='sex')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,size='sex')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='sex',style='sex',size='sex')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='sex',style='smoker',size='size')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='sex',style='smoker')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,col='size',hue='sex')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,col='size',hue='sex',col_wrap=2)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,col='size',hue='sex',col_wrap=3)
plt.show()

# %%
#line plot
sns.relplot(x='total_bill',y='tip',data=df,kind='line')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,kind='line')
plt.show()

# %%
df['sno']=pd.DataFrame(np.arange(1,245))  #add extra column

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  sno
# 0         16.99  1.01  Female     No   Sun  Dinner     2    1
# 1         10.34  1.66    Male     No   Sun  Dinner     3    2
# 2         21.01  3.50    Male     No   Sun  Dinner     3    3
# 3         23.68  3.31    Male     No   Sun  Dinner     2    4
# 4         24.59  3.61  Female     No   Sun  Dinner     4    5
# ..          ...   ...     ...    ...   ...     ...   ...  ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  240
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  241
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  242
# 242       17.82  1.75    Male     No   Sat  Dinner     2  243
# 243       18.78  3.00  Female     No  Thur  Dinner     2  244
#
# [244 rows x 8 columns]

# %%
df['no']=pd.DataFrame(np.arange(10,265))

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  sno   no
# 0         16.99  1.01  Female     No   Sun  Dinner     2    1   10
# 1         10.34  1.66    Male     No   Sun  Dinner     3    2   11
# 2         21.01  3.50    Male     No   Sun  Dinner     3    3   12
# 3         23.68  3.31    Male     No   Sun  Dinner     2    4   13
# 4         24.59  3.61  Female     No   Sun  Dinner     4    5   14
# ..          ...   ...     ...    ...   ...     ...   ...  ...  ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  240  249
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  241  250
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  242  251
# 242       17.82  1.75    Male     No   Sat  Dinner     2  243  252
# 243       18.78  3.00  Female     No  Thur  Dinner     2  244  253
#
# [244 rows x 9 columns]

# %%
sns.relplot(x='sno',y='tip',data=df,kind='line')
plt.show()

# %%
df.drop('sno',axis=1,inplace=True)

# %%
df.drop('no',axis=1,inplace=True)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#joint plot
sns.jointplot(x='total_bill',y='tip',data=df)
plt.show()

# %%
sns.violinplot(x='total_bill',y='day',data=df)
plt.show()

# %%
sns.pairplot(df,vars=continous)
plt.show()

# %%
#Heat map for corelation
c_m=df[['total_bill','tip']].corr()

# %%
c_m
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
sns.heatmap(c_m)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(c_m,annot=True)
plt.show()

# %% [markdown]
# # Plot's Discrete Variables
# # 1)Univariate(single variables)
# #    .Pie plot
# #    .Bar Plot
# #    .Count Plot
# # 2)Bivariate(plot between two variables)
# #    .Boxplot---->one discrete variable and one continous variable)

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.countplot(x='smoker',data=df)
plt.show()

# %%
sns.countplot(y=df['smoker'])
plt.show()

# %%
#bar plot
sns.catplot(x='sex',y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x='sex',y='tip',data=df,kind='bar')
plt.show()

# %%
sns.catplot(x='sex',y='total_bill',data=df,kind='bar',hue='size')
plt.show()

# %%
sns.catplot(x='smoker',y='tip',data=df,kind='bar',hue='day')
plt.show()

# %%
#box plot
sns.boxplot(x='sex',y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x='sex',y='tip',hue='smoker',data=df,kind='box')
plt.show()

# %%
sns.catplot(x='day',y='tip',hue='smoker',data=df,kind='box')
plt.show()
